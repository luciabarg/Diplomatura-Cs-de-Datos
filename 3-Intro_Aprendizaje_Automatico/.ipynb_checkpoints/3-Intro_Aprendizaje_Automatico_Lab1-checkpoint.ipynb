# %% [markdown]
# # Laboratorio 1: Conceptos básicos de aprendizaje automático
# ### Alumna: Lucía Benítez
#
# En este laboratorio les tocará probar con distintos parámetros de los algoritmos de aprendizaje automático aprendidos hasta ahora. La idea es que vean como la selección de atributos, el cambio de hiperparámetros, y los distintos algoritmos afectan los resultados de un regresor o clasificador sobre un conjunto de datos.

# %%
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.image as mpimg
from PIL import Image
import pandas as pd

from matplotlib.colors import ListedColormap
from sklearn.datasets import load_boston, load_breast_cancer, load_iris
from sklearn.linear_model import LinearRegression, LogisticRegression, Perceptron, Ridge
from sklearn.metrics import accuracy_score, confusion_matrix, mean_squared_error
from sklearn.neighbors import KNeighborsClassifier
from sklearn.preprocessing import PolynomialFeatures

from ml.visualization import plot_confusion_matrix, classifier_boundary

np.random.seed(1234)  # Setup seed to be more deterministic

# %matplotlib inline

# %% [markdown]
# ## Regresión
#
# ### Carga de datos

# %%
boston_data = load_boston()

# Utilizamos aproximadamente 80% de los datos para entrenamiento y 20% para validación
shuff_data = np.random.permutation(506)
shuff_train = shuff_data[:400]
shuff_val = shuff_data[400:]

X_train = boston_data['data'][shuff_train]
X_val = boston_data['data'][shuff_val]

y_train = boston_data['target'][shuff_train]
y_val = boston_data['target'][shuff_val]

# Necesario para poder hacer un regresor por feature
feature_map = {feature: idx for idx, feature in enumerate(boston_data['feature_names'])}
#print(feature_map)
print(boston_data['DESCR'])
# Out:
# .. _boston_dataset:
#
# Boston house prices dataset
# ---------------------------
#
# **Data Set Characteristics:**
#
#     :Number of Instances: 506
#
#     :Number of Attributes: 13 numeric/categorical predictive. Median Value (attribute 14) is usually the target.
#
#     :Attribute Information (in order):
#         - CRIM     per capita crime rate by town
#         - ZN       proportion of residential land zoned for lots over 25,000 sq.ft.
#         - INDUS    proportion of non-retail business acres per town
#         - CHAS     Charles River dummy variable (= 1 if tract bounds river; 0 otherwise)
#         - NOX      nitric oxides concentration (parts per 10 million)
#         - RM       average number of rooms per dwelling
#         - AGE      proportion of owner-occupied units built prior to 1940
#         - DIS      weighted distances to five Boston employment centres
#         - RAD      index of accessibility to radial highways
#         - TAX      full-value property-tax rate per $10,000
#         - PTRATIO  pupil-teacher ratio by town
#         - B        1000(Bk - 0.63)^2 where Bk is the proportion of blacks by town
#         - LSTAT    % lower status of the population
#         - MEDV     Median value of owner-occupied homes in $1000's
#
#     :Missing Attribute Values: None
#
#     :Creator: Harrison, D. and Rubinfeld, D.L.
#
# This is a copy of UCI ML housing dataset.
# https://archive.ics.uci.edu/ml/machine-learning-databases/housing/
#
#
# This dataset was taken from the StatLib library which is maintained at Carnegie Mellon University.
#
# The Boston house-price data of Harrison, D. and Rubinfeld, D.L. 'Hedonic
# prices and the demand for clean air', J. Environ. Economics & Management,
# vol.5, 81-102, 1978.   Used in Belsley, Kuh & Welsch, 'Regression diagnostics
# ...', Wiley, 1980.   N.B. Various transformations are used in the table on
# pages 244-261 of the latter.
#
# The Boston house-price data has been used in many machine learning papers that address regression
# problems.
#
# .. topic:: References
#
#    - Belsley, Kuh & Welsch, 'Regression diagnostics: Identifying Influential Data and Sources of Collinearity', Wiley, 1980. 244-261.
#    - Quinlan,R. (1993). Combining Instance-Based and Model-Based Learning. In Proceedings on the Tenth International Conference of Machine Learning, 236-243, University of Massachusetts, Amherst. Morgan Kaufmann.

# %% [markdown]
# ### Regresión sin regularización
#
# Para revisar cómo afecta el cambio de parámetros y los distintos tipos de regresores y atributos (características) al resultado final del algoritmo de aprendizaje automático, lo que se va a hacer es entrenar el regresor tomando sólo un atributo y visualizar eso.
#
# Se busca entrenar utilizando el conjunto de entrenamiento (el terminado en `train`) y evaluar utilizando el conjunto de validación (el terminado en `val`). Luego se visualiza la función calculada para cada conjunto y se la compara.
#
# Los atributos posibles están listados en la descripción del conjunto de datos en la celda anterior. No todos son útiles para visualizar, en particular solo nos interesan los atributos numéricos y descartamos los atributos que se listan a continuación:
#
# - `CHAS`: Atributo categórico (toma valor 0 o 1).
# - `RAD`: Atributo categórico (índice).
# - `MEDV`: Este valor se lo lista como atributo en la descripción del conjunto de datos pero en realidad es el valor de `y`, i.e. es el valor que tratamos de aproximar con el algoritmo de aprendizaje automático.

# %%
#nombre de las columnas del dataset:
feature_map.keys()
# Out:
# dict_keys(['CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD', 'TAX', 'PTRATIO', 'B', 'LSTAT'])

# %%
#eliminamos 'CHAS' y 'RAD':
feature_map.pop('CHAS')
feature_map.pop('RAD')
feature_map.keys()
# Out:
# dict_keys(['CRIM', 'ZN', 'INDUS', 'NOX', 'RM', 'AGE', 'DIS', 'TAX', 'PTRATIO', 'B', 'LSTAT'])

# %%
### Regresión lineal recorriendo todas las columnas del dataset
#https://scikit-learn.org/stable/modules/generated/sklearn.linear_model.LinearRegression.html
for key in feature_map.keys():
    print('\n', key, '\n', 'Media del error cuadrado para:')
    # Seleccionamos un atributo de los listados en la descripción que no sea categórico
    #selected_feature = 'AGE'  # TODO: modificar esto por algún otro valor para ver como cambian los resultados
    selected_feature = key   #recorre todas las columnas del dataset
    feature_col = feature_map[selected_feature]
    X_train_feature = X_train[:, feature_col].reshape(-1, 1)  # Hay que ser que sea una matriz no un vector para que funcione con scikit learn
    X_val_feature = X_val[:, feature_col].reshape(-1, 1)
# Entrenamos un clasificador utilizando sólo ese atributo sobre el conjunto de entrenamiento (X_train, y_train)
    model = LinearRegression()
    model.fit(X_train_feature, y_train)
    # Evaluamos el desempeño del clasificador utilizando la media del error cuadrado (MSE o mean squared error)
    # sobre el conjunto de datos de entrenamiento (X_train, y_train) y lo comparamos con el de validación (X_val, y_val)
    # Mientras más cercano a cero mejor
    print('\t \t \t *','entrenamiento: %.2f' % 
      mean_squared_error(y_train, model.predict(X_train_feature)))
    print('\t \t \t *','validación: %.2f' %
      mean_squared_error(y_val, model.predict(X_val_feature)))
# Out:
#  CRIM
#  Media del error cuadrado para
# 	 	 	 * entrenamiento: 68.25
# 	 	 	 * validación: 86.18
#
#  ZN
#  Media del error cuadrado para
# 	 	 	 * entrenamiento: 74.05
# 	 	 	 * validación: 71.47
#
#  INDUS
#  Media del error cuadrado para
# 	 	 	 * entrenamiento: 62.93
# 	 	 	 * validación: 71.35
#
#  NOX
#  Media del error cuadrado para
# 	 	 	 * entrenamiento: 67.39
# 	 	 	 * validación: 75.32
#
#  RM
#  Media del error cuadrado para
# 	 	 	 * entrenamiento: 36.93
# 	 	 	 * validación: 70.22
#
#  AGE
#  Media del error cuadrado para
# 	 	 	 * entrenamiento: 71.49
# 	 	 	 * validación: 76.07
#
#  DIS
#  Media del error cuadrado para
# 	 	 	 * entrenamiento: 78.66
# 	 	 	 * validación: 81.00
#
#  TAX
#  Media del error cuadrado para
# 	 	 	 * entrenamiento: 62.38
# 	 	 	 * validación: 79.78
#
#  PTRATIO
#  Media del error cuadrado para
# 	 	 	 * entrenamiento: 59.25
# 	 	 	 * validación: 75.98
#
#  B
#  Media del error cuadrado para
# 	 	 	 * entrenamiento: 73.96
# 	 	 	 * validación: 79.11
#
#  LSTAT
#  Media del error cuadrado para
# 	 	 	 * entrenamiento: 36.54
# 	 	 	 * validación: 45.90

# %% [markdown]
# Vemos que la regresión lineal para la mayoría de los atributos no es una buena aproximación, siendo sus errores cuadráticos medios (ECM) mayores del conjunto de entrenamiento al 50% y del conjunto de validación mayores al 70%, excepto para las columnas "RM" (average number of rooms per dwelling) y "LSTAT" (% lower status of the population) que mostraron un ECM para el conjunto de entrenamiento de alrededor del 37% pero para el 70% y 46% respectivamente, por lo que aún teniendo un comportamiento casi lineal, la regresión lineal no es conveniente para este conjunto de datos, lo que verificaremos en las siguientes gráficas:

# %%
chosen_fit=['CRIM','RM','LSTAT']

for chosen in chosen_fit:
    print('\n', chosen, '\n', 'Media del error cuadrado para:')
    # Seleccionamos un atributo de los listados en la descripción que no sea categórico
    #selected_feature = 'AGE'  # TODO: modificar esto por algún otro valor para ver como cambian los resultados
    selected_feature = chosen   #recorre todas las columnas del dataset
    feature_col = feature_map[selected_feature]
    X_train_feature = X_train[:, feature_col].reshape(-1, 1)  # Hay que ser que sea una matriz no un vector para que funcione con scikit learn
    X_val_feature = X_val[:, feature_col].reshape(-1, 1)

# Entrenamos un clasificador utilizando sólo ese atributo sobre el conjunto de entrenamiento (X_train, y_train)
    model = LinearRegression()
    model.fit(X_train_feature, y_train)

    # Evaluamos el desempeño del clasificador utilizando la media del error cuadrado (MSE o mean squared error)
    # sobre el conjunto de datos de entrenamiento (X_train, y_train) y lo comparamos con el de validación (X_val, y_val)
    # Mientras más cercano a cero mejor
    print('\t \t \t *','entrenamiento: %.2f' % 
      mean_squared_error(y_train, model.predict(X_train_feature)))
    print('\t \t \t *','validación: %.2f \n \n ' % 
      mean_squared_error(y_val, model.predict(X_val_feature)))
    
##### Visualización de la regresión lineal
    print('Visualización de la regresión lineal')
    plt.figure(figsize=(12, 5), dpi= 80, facecolor='w', edgecolor='k')

    X_range_start = np.min(np.r_[X_train_feature, X_val_feature])
    X_range_stop = np.max(np.r_[X_train_feature, X_val_feature])
    y_range_start = np.min(np.r_[y_train, y_val])
    y_range_stop = np.max(np.r_[y_train, y_val])
    X_linspace = np.linspace(X_range_start, X_range_stop, 200).reshape(-1, 1)

    # Conjunto de entrenamiento
    plt.subplot(1, 2, 1)
    plt.scatter(X_train_feature, y_train, facecolor="dodgerblue", edgecolor="k", label="datos")
    plt.plot(X_linspace, model.predict(X_linspace), color="tomato", label="modelo")
    plt.ylim(y_range_start, y_range_stop)
    plt.title("Conjunto de Entrenamiento")


    # Conjunto de validación
    plt.subplot(1, 2, 2)
    plt.scatter(X_val_feature, y_val, facecolor="dodgerblue", edgecolor="k", label="datos")
    plt.plot(X_linspace, model.predict(X_linspace), color="tomato", label="modelo")
    plt.ylim(y_range_start, y_range_stop)
    plt.title("Conjunto de Validación")
    #plt.savefig('LSTAT-RL.png')
    plt.show()
# Out:
#  CRIM
#  Media del error cuadrado para:
# 	 	 	 * entrenamiento: 68.25
# 	 	 	 * validación: 86.18
#
#
# Visualización de la regresión lineal
#  RM
#  Media del error cuadrado para:
# 	 	 	 * entrenamiento: 36.93
# 	 	 	 * validación: 70.22
#
#
# Visualización de la regresión lineal
#  LSTAT
#  Media del error cuadrado para:
# 	 	 	 * entrenamiento: 36.54
# 	 	 	 * validación: 45.90
#
#
# Visualización de la regresión lineal

# %% [markdown]
# ### Regresión polinomial
#
# https://scikit-learn.org/stable/modules/generated/sklearn.preprocessing.PolynomialFeatures.html
#
# A su vez, probamos diferentes grados de polinomios a ver cual ajusta mejor las caraterísticas:

# %%
degree=[2,3,4,5,6,10] #probamos varios grados de polinomios

for key in feature_map.keys():
    print('\n')
    print('\t',key)
    # Seleccionamos un atributo de los listados en la descripción que no sea categórico
    selected_feature = key  # TODO: modificar esto por algún otro valor para ver como cambian los resultados
    feature_col = feature_map[selected_feature]
    X_train_feature = X_train[:, feature_col].reshape(-1, 1)  # Hay que ser que sea una matriz no un vector para que funcione con scikit learn
    X_val_feature = X_val[:, feature_col].reshape(-1, 1)

    for polynomial_degree in degree:
        print('grado del polinomio:', polynomial_degree,'\n')
        print('Media del error cuadrado para:')
        poly_features = PolynomialFeatures(polynomial_degree)
        poly_features.fit(X_train_feature)
        X_poly_train = poly_features.transform(X_train_feature)
        X_poly_val = poly_features.transform(X_val_feature)

        model = LinearRegression()
        model.fit(X_poly_train, y_train)

        print('\t \t \t \t *','entrenamiento: %.2f' % 
              mean_squared_error(y_train, model.predict(X_poly_train)))
        print('\t \t \t \t *','validación: %.2f' %
              mean_squared_error(y_val, model.predict(X_poly_val)))
# Out:
# 	 CRIM
# grado del polinomio: 2
#
# Media del error cuadrado para:
# 	 	 	 	 * entrenamiento: 62.99
# 	 	 	 	 * validación: 82.92
# grado del polinomio: 3
#
# Media del error cuadrado para:
# 	 	 	 	 * entrenamiento: 62.02
# 	 	 	 	 * validación: 85.75
# grado del polinomio: 4
#
# Media del error cuadrado para:
# 	 	 	 	 * entrenamiento: 61.97
# 	 	 	 	 * validación: 81.47
# grado del polinomio: 5
#
# Media del error cuadrado para:
# 	 	 	 	 * entrenamiento: 61.97
# 	 	 	 	 * validación: 83.03
# grado del polinomio: 6
#
# Media del error cuadrado para:
# 	 	 	 	 * entrenamiento: 61.96
# 	 	 	 	 * validación: 116.39
# grado del polinomio: 10
#
# Media del error cuadrado para:
# 	 	 	 	 * entrenamiento: 64.79
# 	 	 	 	 * validación: 15128674.21
#
#
# 	 ZN
# grado del polinomio: 2
#
# Media del error cuadrado para:
# 	 	 	 	 * entrenamiento: 72.65
# 	 	 	 	 * validación: 73.71
# grado del polinomio: 3
#
# Media del error cuadrado para:
# 	 	 	 	 * entrenamiento: 69.96
# 	 	 	 	 * validación: 73.46
# grado del polinomio: 4
#
# Media del error cuadrado para:
# 	 	 	 	 * entrenamiento: 69.93
# 	 	 	 	 * validación: 73.45
# grado del polinomio: 5
#
# Media del error cuadrado para:
# 	 	 	 	 * entrenamiento: 69.85
# 	 	 	 	 * validación: 73.61
# grado del polinomio: 6
#
# Media del error cuadrado para:
# 	 	 	 	 * entrenamiento: 69.61
# 	 	 	 	 * validación: 73.40
# grado del polinomio: 10
#
# Media del error cuadrado para:
# 	 	 	 	 * entrenamiento: 69.79
# 	 	 	 	 * validación: 74.50
#
#
# 	 INDUS
# grado del polinomio: 2
#
# Media del error cuadrado para:
# 	 	 	 	 * entrenamiento: 60.15
# 	 	 	 	 * validación: 67.84
# grado del polinomio: 3
#
# Media del error cuadrado para:
# 	 	 	 	 * entrenamiento: 59.98
# 	 	 	 	 * validación: 66.04
# grado del polinomio: 4
#
# Media del error cuadrado para:
# 	 	 	 	 * entrenamiento: 59.54
# 	 	 	 	 * validación: 67.25
# grado del polinomio: 5
#
# Media del error cuadrado para:
# 	 	 	 	 * entrenamiento: 59.54
# 	 	 	 	 * validación: 67.27
# grado del polinomio: 6
#
# Media del error cuadrado para:
# 	 	 	 	 * entrenamiento: 58.84
# 	 	 	 	 * validación: 68.67
# grado del polinomio: 10
#
# Media del error cuadrado para:
# 	 	 	 	 * entrenamiento: 54.37
# 	 	 	 	 * validación: 79.13
#
#
# 	 NOX
# grado del polinomio: 2
#
# Media del error cuadrado para:
# 	 	 	 	 * entrenamiento: 67.22
# 	 	 	 	 * validación: 74.28
# grado del polinomio: 3
#
# Media del error cuadrado para:
# 	 	 	 	 * entrenamiento: 66.34
# 	 	 	 	 * validación: 74.89
# grado del polinomio: 4
#
# Media del error cuadrado para:
# 	 	 	 	 * entrenamiento: 66.28
# 	 	 	 	 * validación: 74.39
# grado del polinomio: 5
#
# Media del error cuadrado para:
# 	 	 	 	 * entrenamiento: 66.26
# 	 	 	 	 * validación: 74.21
# grado del polinomio: 6
#
# Media del error cuadrado para:
# 	 	 	 	 * entrenamiento: 64.30
# 	 	 	 	 * validación: 75.47
# grado del polinomio: 10
#
# Media del error cuadrado para:
# 	 	 	 	 * entrenamiento: 57.99
# 	 	 	 	 * validación: 67.89
#
#
# 	 RM
# grado del polinomio: 2
#
# Media del error cuadrado para:
# 	 	 	 	 * entrenamiento: 34.08
# 	 	 	 	 * validación: 55.56
# grado del polinomio: 3
#
# Media del error cuadrado para:
# 	 	 	 	 * entrenamiento: 32.79
# 	 	 	 	 * validación: 53.96
# grado del polinomio: 4
#
# Media del error cuadrado para:
# 	 	 	 	 * entrenamiento: 31.61
# 	 	 	 	 * validación: 55.60
# grado del polinomio: 5
#
# Media del error cuadrado para:
# 	 	 	 	 * entrenamiento: 30.39
# 	 	 	 	 * validación: 51.89
# grado del polinomio: 6
#
# Media del error cuadrado para:
# 	 	 	 	 * entrenamiento: 30.20
# 	 	 	 	 * validación: 58.19
# grado del polinomio: 10
#
# Media del error cuadrado para:
# 	 	 	 	 * entrenamiento: 29.63
# 	 	 	 	 * validación: 126.98
#
#
# 	 AGE
# grado del polinomio: 2
#
# Media del error cuadrado para:
# 	 	 	 	 * entrenamiento: 70.07
# 	 	 	 	 * validación: 76.42
# grado del polinomio: 3
#
# Media del error cuadrado para:
# 	 	 	 	 * entrenamiento: 69.29
# 	 	 	 	 * validación: 79.91
# grado del polinomio: 4
#
# Media del error cuadrado para:
# 	 	 	 	 * entrenamiento: 68.54
# 	 	 	 	 * validación: 82.60
# grado del polinomio: 5
#
# Media del error cuadrado para:
# 	 	 	 	 * entrenamiento: 68.54
# 	 	 	 	 * validación: 82.59
# grado del polinomio: 6
#
# Media del error cuadrado para:
# 	 	 	 	 * entrenamiento: 68.40
# 	 	 	 	 * validación: 83.67
# grado del polinomio: 10
#
# Media del error cuadrado para:
# 	 	 	 	 * entrenamiento: 68.35
# 	 	 	 	 * validación: 84.58
#
#
# 	 DIS
# grado del polinomio: 2
#
# Media del error cuadrado para:
# 	 	 	 	 * entrenamiento: 75.03
# 	 	 	 	 * validación: 81.73
# grado del polinomio: 3
#
# Media del error cuadrado para:
# 	 	 	 	 * entrenamiento: 73.29
# 	 	 	 	 * validación: 85.28
# grado del polinomio: 4
#
# Media del error cuadrado para:
# 	 	 	 	 * entrenamiento: 72.74
# 	 	 	 	 * validación: 89.64
# grado del polinomio: 5
#
# Media del error cuadrado para:
# 	 	 	 	 * entrenamiento: 72.53
# 	 	 	 	 * validación: 92.83
# grado del polinomio: 6
#
# Media del error cuadrado para:
# 	 	 	 	 * entrenamiento: 71.88
# 	 	 	 	 * validación: 89.16
# grado del polinomio: 10
#
# Media del error cuadrado para:
# 	 	 	 	 * entrenamiento: 68.87
# 	 	 	 	 * validación: 77.05
#
#
# 	 TAX
# grado del polinomio: 2
#
# Media del error cuadrado para:
# 	 	 	 	 * entrenamiento: 62.23
# 	 	 	 	 * validación: 78.62
# grado del polinomio: 3
#
# Media del error cuadrado para:
# 	 	 	 	 * entrenamiento: 62.15
# 	 	 	 	 * validación: 78.41
# grado del polinomio: 4
#
# Media del error cuadrado para:
# 	 	 	 	 * entrenamiento: 62.14
# 	 	 	 	 * validación: 78.62
# grado del polinomio: 5
#
# Media del error cuadrado para:
# 	 	 	 	 * entrenamiento: 62.10
# 	 	 	 	 * validación: 78.72
# grado del polinomio: 6
#
# Media del error cuadrado para:
# 	 	 	 	 * entrenamiento: 62.10
# 	 	 	 	 * validación: 78.67
# grado del polinomio: 10
#
# Media del error cuadrado para:
# 	 	 	 	 * entrenamiento: 61.02
# 	 	 	 	 * validación: 78.80
#
#
# 	 PTRATIO
# grado del polinomio: 2
#
# Media del error cuadrado para:
# 	 	 	 	 * entrenamiento: 58.81
# 	 	 	 	 * validación: 76.20
# grado del polinomio: 3
#
# Media del error cuadrado para:
# 	 	 	 	 * entrenamiento: 58.42
# 	 	 	 	 * validación: 75.56
# grado del polinomio: 4
#
# Media del error cuadrado para:
# 	 	 	 	 * entrenamiento: 54.31
# 	 	 	 	 * validación: 79.30
# grado del polinomio: 5
#
# Media del error cuadrado para:
# 	 	 	 	 * entrenamiento: 53.70
# 	 	 	 	 * validación: 77.59
# grado del polinomio: 6
#
# Media del error cuadrado para:
# 	 	 	 	 * entrenamiento: 52.29
# 	 	 	 	 * validación: 77.44
# grado del polinomio: 10
#
# Media del error cuadrado para:
# 	 	 	 	 * entrenamiento: 52.23
# 	 	 	 	 * validación: 77.66
#
#
# 	 B
# grado del polinomio: 2
#
# Media del error cuadrado para:
# 	 	 	 	 * entrenamiento: 73.73
# 	 	 	 	 * validación: 79.23
# grado del polinomio: 3
#
# Media del error cuadrado para:
# 	 	 	 	 * entrenamiento: 73.72
# 	 	 	 	 * validación: 79.40
# grado del polinomio: 4
#
# Media del error cuadrado para:
# 	 	 	 	 * entrenamiento: 73.57
# 	 	 	 	 * validación: 78.08
# grado del polinomio: 5
#
# Media del error cuadrado para:
# 	 	 	 	 * entrenamiento: 71.89
# 	 	 	 	 * validación: 74.97
# grado del polinomio: 6
#
# Media del error cuadrado para:
# 	 	 	 	 * entrenamiento: 70.61
# 	 	 	 	 * validación: 73.05
# grado del polinomio: 10
#
# Media del error cuadrado para:
# 	 	 	 	 * entrenamiento: 69.47
# 	 	 	 	 * validación: 73.82
#
#
# 	 LSTAT
# grado del polinomio: 2
#
# Media del error cuadrado para:
# 	 	 	 	 * entrenamiento: 28.47
# 	 	 	 	 * validación: 37.45
# grado del polinomio: 3
#
# Media del error cuadrado para:
# 	 	 	 	 * entrenamiento: 26.62
# 	 	 	 	 * validación: 38.00
# grado del polinomio: 4
#
# Media del error cuadrado para:
# 	 	 	 	 * entrenamiento: 25.55
# 	 	 	 	 * validación: 35.51
# grado del polinomio: 5
#
# Media del error cuadrado para:
# 	 	 	 	 * entrenamiento: 24.85
# 	 	 	 	 * validación: 35.27
# grado del polinomio: 6
#
# Media del error cuadrado para:
# 	 	 	 	 * entrenamiento: 24.85
# 	 	 	 	 * validación: 35.11
# grado del polinomio: 10
#
# Media del error cuadrado para:
# 	 	 	 	 * entrenamiento: 24.69
# 	 	 	 	 * validación: 35.93

# %% [markdown]
# Nuevamente, de la regresión polinomial, podemos notar que para la gran mayoría de los atributos su ECM es superior al 50%, exceptuando para 'RM' y 'LSTAT'. Además, a medida que aumenta el grado del polinomio, se puede observar un punto en que el ECM del conjunto de entrenamiento es menor, pero el del conjunto de validación que iba bajando, aumenta, lo que indica posiblemente ya el caso de overfitting.

# %%
chosen_fit=['CRIM','RM','LSTAT']
degree=[2,3,4,5,6,10] #probamos varios grados de polinomios

for chosen in chosen_fit:
    print('\n')
    print('\t',chosen)
    # Seleccionamos un atributo de los listados en la descripción que no sea categórico
    selected_feature = chosen  # TODO: modificar esto por algún otro valor para ver como cambian los resultados
    feature_col = feature_map[selected_feature]
    X_train_feature = X_train[:, feature_col].reshape(-1, 1)  # Hay que ser que sea una matriz no un vector para que funcione con scikit learn
    X_val_feature = X_val[:, feature_col].reshape(-1, 1)

    for polynomial_degree in degree:
        print('grado del polinomio:', polynomial_degree,'\n')
        print('Media del error cuadrado para:')
        poly_features = PolynomialFeatures(polynomial_degree)
        poly_features.fit(X_train_feature)
        X_poly_train = poly_features.transform(X_train_feature)
        X_poly_val = poly_features.transform(X_val_feature)

        model = LinearRegression()
        model.fit(X_poly_train, y_train)

        print('\t \t \t \t *','entrenamiento: %.2f' % 
              mean_squared_error(y_train, model.predict(X_poly_train)))
        print('\t \t \t \t *','validación: %.2f' %
              mean_squared_error(y_val, model.predict(X_poly_val)))

        plt.figure(figsize=(14, 5), dpi=80, facecolor='w', edgecolor='k')

        X_range_start = np.min(np.r_[X_train_feature, X_val_feature])
        X_range_stop = np.max(np.r_[X_train_feature, X_val_feature])
        y_range_start = np.min(np.r_[y_train, y_val])
        y_range_stop = np.max(np.r_[y_train, y_val])
        X_linspace = np.linspace(X_range_start, X_range_stop, 200).reshape(-1, 1)
        X_linspace_poly = poly_features.transform(X_linspace)

        # Conjunto de entrenamiento
        plt.subplot(1, 2, 1)
        plt.scatter(X_train_feature, y_train, facecolor="dodgerblue", edgecolor="k", label="datos")
        plt.plot(X_linspace, model.predict(X_linspace_poly), color="tomato", label="modelo")
        plt.ylim(y_range_start, y_range_stop)
        plt.title("Conjunto de Entrenamiento")

        # Conjunto de validación
        plt.subplot(1, 2, 2)
        plt.scatter(X_val_feature, y_val, facecolor="dodgerblue", edgecolor="k", label="datos")
        plt.plot(X_linspace, model.predict(X_linspace_poly), color="tomato", label="modelo")
        plt.ylim(y_range_start, y_range_stop)
        plt.title("Conjunto de Validación")
        #plt.savefig('CRIM-pl_gr7.png')
        plt.show()
# Out:
# 	 CRIM
# grado del polinomio: 2
#
# Media del error cuadrado para:
# 	 	 	 	 * entrenamiento: 62.99
# 	 	 	 	 * validación: 82.92
# grado del polinomio: 3
#
# Media del error cuadrado para:
# 	 	 	 	 * entrenamiento: 62.02
# 	 	 	 	 * validación: 85.75
# grado del polinomio: 4
#
# Media del error cuadrado para:
# 	 	 	 	 * entrenamiento: 61.97
# 	 	 	 	 * validación: 81.47
# grado del polinomio: 5
#
# Media del error cuadrado para:
# 	 	 	 	 * entrenamiento: 61.97
# 	 	 	 	 * validación: 83.03
# grado del polinomio: 6
#
# Media del error cuadrado para:
# 	 	 	 	 * entrenamiento: 61.96
# 	 	 	 	 * validación: 116.39
# grado del polinomio: 10
#
# Media del error cuadrado para:
# 	 	 	 	 * entrenamiento: 64.79
# 	 	 	 	 * validación: 15128674.21
# 	 RM
# grado del polinomio: 2
#
# Media del error cuadrado para:
# 	 	 	 	 * entrenamiento: 34.08
# 	 	 	 	 * validación: 55.56
# grado del polinomio: 3
#
# Media del error cuadrado para:
# 	 	 	 	 * entrenamiento: 32.79
# 	 	 	 	 * validación: 53.96
# grado del polinomio: 4
#
# Media del error cuadrado para:
# 	 	 	 	 * entrenamiento: 31.61
# 	 	 	 	 * validación: 55.60
# grado del polinomio: 5
#
# Media del error cuadrado para:
# 	 	 	 	 * entrenamiento: 30.39
# 	 	 	 	 * validación: 51.89
# grado del polinomio: 6
#
# Media del error cuadrado para:
# 	 	 	 	 * entrenamiento: 30.20
# 	 	 	 	 * validación: 58.19
# grado del polinomio: 10
#
# Media del error cuadrado para:
# 	 	 	 	 * entrenamiento: 29.63
# 	 	 	 	 * validación: 126.98
# 	 LSTAT
# grado del polinomio: 2
#
# Media del error cuadrado para:
# 	 	 	 	 * entrenamiento: 28.47
# 	 	 	 	 * validación: 37.45
# grado del polinomio: 3
#
# Media del error cuadrado para:
# 	 	 	 	 * entrenamiento: 26.62
# 	 	 	 	 * validación: 38.00
# grado del polinomio: 4
#
# Media del error cuadrado para:
# 	 	 	 	 * entrenamiento: 25.55
# 	 	 	 	 * validación: 35.51
# grado del polinomio: 5
#
# Media del error cuadrado para:
# 	 	 	 	 * entrenamiento: 24.85
# 	 	 	 	 * validación: 35.27
# grado del polinomio: 6
#
# Media del error cuadrado para:
# 	 	 	 	 * entrenamiento: 24.85
# 	 	 	 	 * validación: 35.11
# grado del polinomio: 10
#
# Media del error cuadrado para:
# 	 	 	 	 * entrenamiento: 24.69
# 	 	 	 	 * validación: 35.93

# %% [markdown]
# Para 'CRIM', el overfitting se produce alrededor del 5to grado del polinomio, alcanzando un buen ajuste con el grado del polinomio igual a 4. Para 'RM', ocurre con el grado igual a 4, mientras que su mejor ajuste se corresponde a un polinomio de 3er grado. Mientras que para la columna 'LSTAT', el ajuste con menor ECM en ambos conjuntos se corresponde a un polinomio de grado 6, ocurriendo un overfitting a grados altos, en este caso igual a 10.

# %% [markdown]
# ### Regresión lineal con regularización
#
# - https://scikit-learn.org/stable/modules/linear_model.html#ridge-regression
# - https://scikit-learn.org/stable/modules/generated/sklearn.linear_model.Ridge.html
#
# Seleccionamos para analizar los atributos 'RM' (average number of rooms per dwelling) y 'CRIM' per capita crime rate by town)

# %%
chosen_fit=['CRIM','RM','LSTAT']
regularizacion = [0.00001, 0.01, 100 ,10000]

for chosen in chosen_fit:
    print('\n')
    print('\t',chosen)
    selected_feature = chosen  # TODO: modificar esto por algún otro valor para ver como cambian los resultados
    feature_col = feature_map[selected_feature]
    X_train_feature = X_train[:, feature_col].reshape(-1, 1)  # Hay que ser que sea una matriz no un vector para que funcione con scikit learn
    X_val_feature = X_val[:, feature_col].reshape(-1, 1)


    for alpha in regularizacion:
        model = Ridge(alpha=alpha)
        model.fit(X_train_feature, y_train)
        print('\t','alpha=',alpha)
        print('\t \t \t \t *','entrenamiento: %.2f' % 
              mean_squared_error(y_train, model.predict(X_train_feature)))
        print('\t \t \t \t *','validación: %.2f' %
              mean_squared_error(y_val, model.predict(X_val_feature)))


        plt.figure(figsize=(14, 5), dpi= 80, facecolor='w', edgecolor='k')

        X_range_start = np.min(np.r_[X_train_feature, X_val_feature])
        X_range_stop = np.max(np.r_[X_train_feature, X_val_feature])
        y_range_start = np.min(np.r_[y_train, y_val])
        y_range_stop = np.max(np.r_[y_train, y_val])
        X_linspace = np.linspace(X_range_start, X_range_stop, 200).reshape(-1, 1)

        # Conjunto de entrenamiento
        plt.subplot(1, 2, 1)
        plt.scatter(X_train_feature, y_train, facecolor="dodgerblue", edgecolor="k", label="datos")
        plt.plot(X_linspace, model.predict(X_linspace), color="tomato", label="modelo")
        plt.ylim(y_range_start, y_range_stop)
        plt.title("Conjunto de Entrenamiento")

        # Conjunto de validación
        plt.subplot(1, 2, 2)
        plt.scatter(X_val_feature, y_val, facecolor="dodgerblue", edgecolor="k", label="datos")
        plt.plot(X_linspace, model.predict(X_linspace), color="tomato", label="modelo")
        plt.ylim(y_range_start, y_range_stop)
        plt.title("Conjunto de Validación")

        plt.show()
# Out:
# 	 CRIM
# 	 alpha= 1e-05
# 	 	 	 	 * entrenamiento: 68.25
# 	 	 	 	 * validación: 86.18
# 	 alpha= 0.01
# 	 	 	 	 * entrenamiento: 68.25
# 	 	 	 	 * validación: 86.18
# 	 alpha= 100
# 	 	 	 	 * entrenamiento: 68.25
# 	 	 	 	 * validación: 86.10
# 	 alpha= 10000
# 	 	 	 	 * entrenamiento: 69.38
# 	 	 	 	 * validación: 81.74
#
#
# 	 RM
# 	 alpha= 1e-05
# 	 	 	 	 * entrenamiento: 36.93
# 	 	 	 	 * validación: 70.22
# 	 alpha= 0.01
# 	 	 	 	 * entrenamiento: 36.93
# 	 	 	 	 * validación: 70.22
# 	 alpha= 100
# 	 	 	 	 * entrenamiento: 42.28
# 	 	 	 	 * validación: 64.56
# 	 alpha= 10000
# 	 	 	 	 * entrenamiento: 82.60
# 	 	 	 	 * validación: 83.26
#
#
# 	 LSTAT
# 	 alpha= 1e-05
# 	 	 	 	 * entrenamiento: 36.54
# 	 	 	 	 * validación: 45.90
# 	 alpha= 0.01
# 	 	 	 	 * entrenamiento: 36.54
# 	 	 	 	 * validación: 45.90
# 	 alpha= 100
# 	 	 	 	 * entrenamiento: 36.54
# 	 	 	 	 * validación: 45.86
# 	 alpha= 10000
# 	 	 	 	 * entrenamiento: 41.70
# 	 	 	 	 * validación: 48.26

# %% [markdown]
# se puede ver que en un rango amplio, no afecta el alpha pero si tiene un valor grande, el ECM se incrementa

# %% [markdown]
# ### Regresión polinomial con regularización
# Eligiendo la característica 'LSTAT' que en todos los casos tuvo el menor ECM, continuamos el análisis:

# %%
selected_feature = 'LSTAT'  
feature_col = feature_map[selected_feature]
X_train_feature = X_train[:, feature_col].reshape(-1, 1)  # Hay que ser que sea una matriz no un vector para que funcione con scikit learn
X_val_feature = X_val[:, feature_col].reshape(-1, 1)

degree = [2,3,4,6,15]
param = [0.00001, 0.01, 100 ,1000]

print('feature=',selected_feature)
for polynomial_degree in degree: # TODO: Grado del polinomio.
    print('\n')
    print('\t','polynomial_degree=',polynomial_degree)
    for alpha in param: # TODO: Grado del polinomio.
    #alpha = 2.2 # TODO: Parámetro de regularización. También denominado como parámetro `lambda`.
#         print('\n')
        print('\t','alpha=',alpha)
        poly_features = PolynomialFeatures(polynomial_degree)
        poly_features.fit(X_train_feature)
        X_poly_train = poly_features.transform(X_train_feature)
        X_poly_val = poly_features.transform(X_val_feature)

        model = Ridge(alpha=alpha)
        model.fit(X_poly_train, y_train)

        print('Media del error cuadrado para entrenamiento: %.2f' % 
              mean_squared_error(y_train, model.predict(X_poly_train)))
        print('Media del error cuadrado para validación: %.2f' %
              mean_squared_error(y_val, model.predict(X_poly_val)))
        
        
        plt.figure(figsize=(14, 5), dpi= 80, facecolor='w', edgecolor='k')

        X_range_start = np.min(np.r_[X_train_feature, X_val_feature])
        X_range_stop = np.max(np.r_[X_train_feature, X_val_feature])
        y_range_start = np.min(np.r_[y_train, y_val])
        y_range_stop = np.max(np.r_[y_train, y_val])
        X_linspace = np.linspace(X_range_start, X_range_stop, 200).reshape(-1, 1)
        X_linspace_poly = poly_features.transform(X_linspace)

        # Conjunto de entrenamiento
        plt.subplot(1, 2, 1)
        plt.scatter(X_train_feature, y_train, facecolor="dodgerblue", edgecolor="k", label="datos")
        plt.plot(X_linspace, model.predict(X_linspace_poly), color="tomato", label="modelo")
        plt.ylim(y_range_start, y_range_stop)
        plt.title("Conjunto de Entrenamiento")

        # Conjunto de validación
        plt.subplot(1, 2, 2)
        plt.scatter(X_val_feature, y_val, facecolor="dodgerblue", edgecolor="k", label="datos")
        plt.plot(X_linspace, model.predict(X_linspace_poly), color="tomato", label="modelo")
        plt.ylim(y_range_start, y_range_stop)
        plt.title("Conjunto de Validación")

        plt.show()
# Out:
# feature= LSTAT
#
#
# 	 polynomial_degree= 2
# 	 alpha= 1e-05
# Media del error cuadrado para entrenamiento: 28.47
# Media del error cuadrado para validación: 37.45
# 	 alpha= 0.01
# Media del error cuadrado para entrenamiento: 28.47
# Media del error cuadrado para validación: 37.45
# 	 alpha= 100
# Media del error cuadrado para entrenamiento: 28.55
# Media del error cuadrado para validación: 37.29
# 	 alpha= 1000
# Media del error cuadrado para entrenamiento: 31.87
# Media del error cuadrado para validación: 39.99
# 	 polynomial_degree= 3
# 	 alpha= 1e-05
# Media del error cuadrado para entrenamiento: 26.62
# Media del error cuadrado para validación: 38.00
# 	 alpha= 0.01
# Media del error cuadrado para entrenamiento: 26.62
# Media del error cuadrado para validación: 38.00
# 	 alpha= 100
# Media del error cuadrado para entrenamiento: 27.60
# Media del error cuadrado para validación: 36.85
# 	 alpha= 1000
# Media del error cuadrado para entrenamiento: 32.64
# Media del error cuadrado para validación: 40.42
# 	 polynomial_degree= 4
# 	 alpha= 1e-05
# Media del error cuadrado para entrenamiento: 25.55
# Media del error cuadrado para validación: 35.51
# /home/lucia/anaconda3/envs/p36workshop/lib/python3.6/site-packages/sklearn/linear_model/ridge.py:125: LinAlgWarning: Ill-conditioned matrix (rcond=4.80053e-19): result may not be accurate.
#   overwrite_a=True).T
# 	 alpha= 0.01
# Media del error cuadrado para entrenamiento: 25.55
# Media del error cuadrado para validación: 35.51
# 	 alpha= 100
# Media del error cuadrado para entrenamiento: 28.13
# Media del error cuadrado para validación: 38.84
# 	 alpha= 1000
# Media del error cuadrado para entrenamiento: 30.09
# Media del error cuadrado para validación: 41.59
# 	 polynomial_degree= 6
# 	 alpha= 1e-05
# Media del error cuadrado para entrenamiento: 24.85
# Media del error cuadrado para validación: 35.11
# /home/lucia/anaconda3/envs/p36workshop/lib/python3.6/site-packages/sklearn/linear_model/ridge.py:125: LinAlgWarning: Ill-conditioned matrix (rcond=4.30393e-25): result may not be accurate.
#   overwrite_a=True).T
# 	 alpha= 0.01
# Media del error cuadrado para entrenamiento: 24.85
# Media del error cuadrado para validación: 35.12
# /home/lucia/anaconda3/envs/p36workshop/lib/python3.6/site-packages/sklearn/linear_model/ridge.py:125: LinAlgWarning: Ill-conditioned matrix (rcond=4.30393e-22): result may not be accurate.
#   overwrite_a=True).T
# 	 alpha= 100
# Media del error cuadrado para entrenamiento: 25.71
# Media del error cuadrado para validación: 39.27
# /home/lucia/anaconda3/envs/p36workshop/lib/python3.6/site-packages/sklearn/linear_model/ridge.py:125: LinAlgWarning: Ill-conditioned matrix (rcond=3.79287e-18): result may not be accurate.
#   overwrite_a=True).T
# 	 alpha= 1000
# Media del error cuadrado para entrenamiento: 26.30
# Media del error cuadrado para validación: 37.52
# /home/lucia/anaconda3/envs/p36workshop/lib/python3.6/site-packages/sklearn/linear_model/ridge.py:125: LinAlgWarning: Ill-conditioned matrix (rcond=4.30393e-17): result may not be accurate.
#   overwrite_a=True).T
# 	 polynomial_degree= 15
# 	 alpha= 1e-05
# Media del error cuadrado para entrenamiento: 3815.46
# Media del error cuadrado para validación: 6042.81
# 	 alpha= 0.01
# Media del error cuadrado para entrenamiento: 3813.44
# Media del error cuadrado para validación: 6036.67
# 	 alpha= 100
# Media del error cuadrado para entrenamiento: 1723.39
# Media del error cuadrado para validación: 1577.81
# 	 alpha= 1000
# Media del error cuadrado para entrenamiento: 1481.68
# Media del error cuadrado para validación: 1409.32

# %% [markdown]
# El mejor ajuste se obtiene con el alpha y el grado de polinomio que daban menor ECM en los casos anteriores analizados, para LSTAT, sería el caso de polinomio de grado 6 y con un alpha menor a 0.01

# %% [markdown]
# ## Clasificación binaria
#
# La clasificación binaria tiene dos posibles etiquetas para su clasificación: SI y NO (o 0 y 1, o -1 y 1). Nuevamente, se busca entrenar utilizando el conjunto de entrenamiento (el terminado en `train`) y evaluar utilizando el conjunto de validación (el terminado en `val`). Luego se visualiza la función calculada para cada conjunto y se la compara.
#
# Similar al caso anterior, para poder visualizar los distintos atributos y cómo estos afectan el modelo, debemos hacer uso de una selección de atributos a mano. En este caso todos los atributos son válidos, puesto que todos son numéricos. Como tenemos una clasificación, lo que buscamos ver es la frontera de decisión eligiendo distintos atributos y parámetros para distintos clasificadores. En este caso elegimos 2 atributos ya que la clase se representará por color dentro del gráfico.
#
# ### Carga de datos

# %%
breast_cancer_data = load_breast_cancer()

# Utilizamos aproximadamente 80% de los datos para entrenamiento y 20% para validación
shuff_data = np.random.permutation(569)
shuff_train = shuff_data[:400]
shuff_val = shuff_data[400:]

X_train = breast_cancer_data['data'][shuff_train]
X_val = breast_cancer_data['data'][shuff_val]

y_train = breast_cancer_data['target'][shuff_train]
y_val = breast_cancer_data['target'][shuff_val]

feature_map = {feature: idx for idx, feature in enumerate(breast_cancer_data['feature_names'])}

print(breast_cancer_data['DESCR'])
# Out:
# .. _breast_cancer_dataset:
#
# Breast cancer wisconsin (diagnostic) dataset
# --------------------------------------------
#
# **Data Set Characteristics:**
#
#     :Number of Instances: 569
#
#     :Number of Attributes: 30 numeric, predictive attributes and the class
#
#     :Attribute Information:
#         - radius (mean of distances from center to points on the perimeter)
#         - texture (standard deviation of gray-scale values)
#         - perimeter
#         - area
#         - smoothness (local variation in radius lengths)
#         - compactness (perimeter^2 / area - 1.0)
#         - concavity (severity of concave portions of the contour)
#         - concave points (number of concave portions of the contour)
#         - symmetry
#         - fractal dimension ("coastline approximation" - 1)
#
#         The mean, standard error, and "worst" or largest (mean of the three
#         largest values) of these features were computed for each image,
#         resulting in 30 features.  For instance, field 3 is Mean Radius, field
#         13 is Radius SE, field 23 is Worst Radius.
#
#         - class:
#                 - WDBC-Malignant
#                 - WDBC-Benign
#
#     :Summary Statistics:
#
#     ===================================== ====== ======
#                                            Min    Max
#     ===================================== ====== ======
#     radius (mean):                        6.981  28.11
#     texture (mean):                       9.71   39.28
#     perimeter (mean):                     43.79  188.5
#     area (mean):                          143.5  2501.0
#     smoothness (mean):                    0.053  0.163
#     compactness (mean):                   0.019  0.345
#     concavity (mean):                     0.0    0.427
#     concave points (mean):                0.0    0.201
#     symmetry (mean):                      0.106  0.304
#     fractal dimension (mean):             0.05   0.097
#     radius (standard error):              0.112  2.873
#     texture (standard error):             0.36   4.885
#     perimeter (standard error):           0.757  21.98
#     area (standard error):                6.802  542.2
#     smoothness (standard error):          0.002  0.031
#     compactness (standard error):         0.002  0.135
#     concavity (standard error):           0.0    0.396
#     concave points (standard error):      0.0    0.053
#     symmetry (standard error):            0.008  0.079
#     fractal dimension (standard error):   0.001  0.03
#     radius (worst):                       7.93   36.04
#     texture (worst):                      12.02  49.54
#     perimeter (worst):                    50.41  251.2
#     area (worst):                         185.2  4254.0
#     smoothness (worst):                   0.071  0.223
#     compactness (worst):                  0.027  1.058
#     concavity (worst):                    0.0    1.252
#     concave points (worst):               0.0    0.291
#     symmetry (worst):                     0.156  0.664
#     fractal dimension (worst):            0.055  0.208
#     ===================================== ====== ======
#
#     :Missing Attribute Values: None
#
#     :Class Distribution: 212 - Malignant, 357 - Benign
#
#     :Creator:  Dr. William H. Wolberg, W. Nick Street, Olvi L. Mangasarian
#
#     :Donor: Nick Street
#
#     :Date: November, 1995
#
# This is a copy of UCI ML Breast Cancer Wisconsin (Diagnostic) datasets.
# https://goo.gl/U2Uwz2
#
# Features are computed from a digitized image of a fine needle
# aspirate (FNA) of a breast mass.  They describe
# characteristics of the cell nuclei present in the image.
#
# Separating plane described above was obtained using
# Multisurface Method-Tree (MSM-T) [K. P. Bennett, "Decision Tree
# Construction Via Linear Programming." Proceedings of the 4th
# Midwest Artificial Intelligence and Cognitive Science Society,
# pp. 97-101, 1992], a classification method which uses linear
# programming to construct a decision tree.  Relevant features
# were selected using an exhaustive search in the space of 1-4
# features and 1-3 separating planes.
#
# The actual linear program used to obtain the separating plane
# in the 3-dimensional space is that described in:
# [K. P. Bennett and O. L. Mangasarian: "Robust Linear
# Programming Discrimination of Two Linearly Inseparable Sets",
# Optimization Methods and Software 1, 1992, 23-34].
#
# This database is also available through the UW CS ftp server:
#
# ftp ftp.cs.wisc.edu
# cd math-prog/cpo-dataset/machine-learn/WDBC/
#
# .. topic:: References
#
#    - W.N. Street, W.H. Wolberg and O.L. Mangasarian. Nuclear feature extraction
#      for breast tumor diagnosis. IS&T/SPIE 1993 International Symposium on
#      Electronic Imaging: Science and Technology, volume 1905, pages 861-870,
#      San Jose, CA, 1993.
#    - O.L. Mangasarian, W.N. Street and W.H. Wolberg. Breast cancer diagnosis and
#      prognosis via linear programming. Operations Research, 43(4), pages 570-577,
#      July-August 1995.
#    - W.H. Wolberg, W.N. Street, and O.L. Mangasarian. Machine learning techniques
#      to diagnose breast cancer from fine-needle aspirates. Cancer Letters 77 (1994)
#      163-171.

# %%
print("Listado de atributos\n====================")
for feature in breast_cancer_data['feature_names']:
    print("- %s" % feature)
# Out:
# Listado de atributos
# ====================
# - mean radius
# - mean texture
# - mean perimeter
# - mean area
# - mean smoothness
# - mean compactness
# - mean concavity
# - mean concave points
# - mean symmetry
# - mean fractal dimension
# - radius error
# - texture error
# - perimeter error
# - area error
# - smoothness error
# - compactness error
# - concavity error
# - concave points error
# - symmetry error
# - fractal dimension error
# - worst radius
# - worst texture
# - worst perimeter
# - worst area
# - worst smoothness
# - worst compactness
# - worst concavity
# - worst concave points
# - worst symmetry
# - worst fractal dimension

# %%
# Seleccionamos dos atributo de los listados en el apartado anterior, uno para el eje x y otro para el eje y
# TODO: cambiar con estos features
x_feature = 'mean fractal dimension'
y_feature = 'mean compactness'

x_feature_col = feature_map[x_feature]
y_feature_col = feature_map[y_feature]
X_train_feature = X_train[:, [x_feature_col, y_feature_col]]
X_val_feature = X_val[:, [x_feature_col, y_feature_col]]

# %% [markdown]
# ### Perceptrón
#
# https://scikit-learn.org/stable/modules/generated/sklearn.linear_model.Perceptron.html

# %%
print('x_feature = ',x_feature,'\n','y_feature = ',y_feature )
print('alpha=',0.0001)
alpha=0.0001
regularizacion=['l1','l2', 'elasticnet']

for penalty in regularizacion:# TODO: Tipo de regularización: l1 (valor absoluto), l2 (cuadrados), elasticnet (l1 + l2).
    print('\n','penalty=',penalty )
    
    #for alpha in param: #= 0.01# TODO: Parámetro de regularización. También denominado como parámetro `lambda`.
    #print('\n','alpha=',alpha)
    max_iter = 1000 # TODO: Cantidad máxima de iteraciones del algoritmo
    model = Perceptron(penalty=penalty, alpha=alpha, max_iter=max_iter)
    model.fit(X_train_feature, y_train)

    # Evaluamos el desempeño del clasificador utilizando la exactitud (accuracy) sobre el conjunto
    # de datos de entrenamiento (X_train, y_train) y lo comparamos con el de validación (X_val, y_val)
    # La exactitud toma valor en el rango [0, 1] donde más alto es mejor
    print('Exactitud para entrenamiento: %.2f' %  accuracy_score(y_train, model.predict(X_train_feature)))
    print('Exactitud para validación: %.2f' % accuracy_score(y_val, model.predict(X_val_feature)))
        
    
    plt.figure(figsize=(14, 10), dpi= 80, facecolor='w', edgecolor='k')

    plt.subplot(2, 2, 1)
    plot_confusion_matrix(confusion_matrix(y_train, model.predict(X_train_feature)),
                          classes=breast_cancer_data.target_names,
                          title='Matriz de confusión para entrenamiento (sin normalizar)')
    plt.subplot(2, 2, 3)
    plot_confusion_matrix(confusion_matrix(y_train, model.predict(X_train_feature)),
                          classes=breast_cancer_data.target_names, normalize=True,
                          title='Matriz de confusión para entrenamiento (normalizando)')

    plt.subplot(2, 2, 2)
    plot_confusion_matrix(confusion_matrix(y_val, model.predict(X_val_feature)),
                          classes=breast_cancer_data.target_names,
                          title='Matriz de confusión para validación (sin normalizar)')
    plt.subplot(2, 2, 4)
    plot_confusion_matrix(confusion_matrix(y_val, model.predict(X_val_feature)),
                          classes=breast_cancer_data.target_names, normalize=True,
                          title='Matriz de confusión para validación (normalizando)')

    plt.show()
# Out:
# x_feature =  mean fractal dimension
#  y_feature =  mean compactness
# alpha= 0.0001
#
#  penalty= l1
# Exactitud para entrenamiento: 0.88
# Exactitud para validación: 0.89
# /home/lucia/anaconda3/envs/p36workshop/lib/python3.6/site-packages/sklearn/linear_model/stochastic_gradient.py:183: FutureWarning: max_iter and tol parameters have been added in Perceptron in 0.19. If max_iter is set but tol is left unset, the default value for tol in 0.19 and 0.20 will be None (which is equivalent to -infinity, so it has no effect) but will change in 0.21 to 1e-3. Specify tol to silence this warning.
#   FutureWarning)
#  penalty= l2
# Exactitud para entrenamiento: 0.80
# Exactitud para validación: 0.80
# /home/lucia/anaconda3/envs/p36workshop/lib/python3.6/site-packages/sklearn/linear_model/stochastic_gradient.py:183: FutureWarning: max_iter and tol parameters have been added in Perceptron in 0.19. If max_iter is set but tol is left unset, the default value for tol in 0.19 and 0.20 will be None (which is equivalent to -infinity, so it has no effect) but will change in 0.21 to 1e-3. Specify tol to silence this warning.
#   FutureWarning)
#  penalty= elasticnet
# Exactitud para entrenamiento: 0.80
# Exactitud para validación: 0.80
# /home/lucia/anaconda3/envs/p36workshop/lib/python3.6/site-packages/sklearn/linear_model/stochastic_gradient.py:183: FutureWarning: max_iter and tol parameters have been added in Perceptron in 0.19. If max_iter is set but tol is left unset, the default value for tol in 0.19 and 0.20 will be None (which is equivalent to -infinity, so it has no effect) but will change in 0.21 to 1e-3. Specify tol to silence this warning.
#   FutureWarning)

# %% [markdown]
# el mejor ajuste se encuentra con el método 'l1'

# %% [markdown]
# #### Matriz de confusión
#
# La matriz de confusión sirve en clasificación para ver que tanto se desviaron las instancias (de entrenamiento o de validación) de su valor real.

# %%
plt.figure(figsize=(14, 10), dpi= 80, facecolor='w', edgecolor='k')

plt.subplot(2, 2, 1)
plot_confusion_matrix(confusion_matrix(y_train, model.predict(X_train_feature)),
                      classes=breast_cancer_data.target_names,
                      title='Matriz de confusión para entrenamiento (sin normalizar)')
plt.subplot(2, 2, 3)
plot_confusion_matrix(confusion_matrix(y_train, model.predict(X_train_feature)),
                      classes=breast_cancer_data.target_names, normalize=True,
                      title='Matriz de confusión para entrenamiento (normalizando)')

plt.subplot(2, 2, 2)
plot_confusion_matrix(confusion_matrix(y_val, model.predict(X_val_feature)),
                      classes=breast_cancer_data.target_names,
                      title='Matriz de confusión para validación (sin normalizar)')
plt.subplot(2, 2, 4)
plot_confusion_matrix(confusion_matrix(y_val, model.predict(X_val_feature)),
                      classes=breast_cancer_data.target_names, normalize=True,
                      title='Matriz de confusión para validación (normalizando)')

plt.show()

# %% [markdown]
# #### Visualización de la frontera de decisión

# %%
plt.figure(figsize=(14, 5), dpi=80, facecolor='w', edgecolor='k')

xx, yy, Z = classifier_boundary(np.r_[X_train_feature, X_val_feature], model)

cmap_dots = ListedColormap(['tomato', 'dodgerblue'])
cmap_back = ListedColormap(['lightcoral', 'skyblue'])

# Conjunto de entrenamiento
plt.subplot(1, 2, 1)
plt.pcolormesh(xx, yy, Z, cmap=cmap_back)
plt.scatter(X_train_feature[:, 0], X_train_feature[:, 1], c=y_train, cmap=cmap_dots, edgecolor='k', s=20)
plt.xlim(xx.min(), xx.max())
plt.ylim(yy.min(), yy.max())
plt.xlabel(x_feature)
plt.ylabel(y_feature)
plt.title("Conjunto de Entrenamiento")

# Conjunto de validación
plt.subplot(1, 2, 2)
plt.pcolormesh(xx, yy, Z, cmap=cmap_back)
plt.scatter(X_val_feature[:, 0], X_val_feature[:, 1], c=y_val, cmap=cmap_dots, edgecolor='k', s=20)
plt.xlim(xx.min(), xx.max())
plt.ylim(yy.min(), yy.max())
plt.xlabel(x_feature)
plt.ylabel(y_feature)
plt.title("Conjunto de Validación")

plt.show()

# %% [markdown]
# ### Regresión logística
#
# https://scikit-learn.org/stable/modules/generated/sklearn.linear_model.LogisticRegression.html

# %%
penalty = 'l1'  # TODO: Tipo de regularización: l1 (valor absoluto), l2 (cuadrados).
alpha =0.001  # TODO: Parámetro de regularización. También denominado como parámetro `lambda`. Debe ser mayor que 0.

model = LogisticRegression(penalty=penalty, C=1./alpha)
model.fit(X_train_feature, y_train)

print('Exactitud para entrenamiento: %.2f' %  accuracy_score(y_train, model.predict(X_train_feature)))
print('Exactitud para validación: %.2f' % accuracy_score(y_val, model.predict(X_val_feature)))
# Out:
# Exactitud para entrenamiento: 0.87
# Exactitud para validación: 0.88
# /home/lucia/anaconda3/envs/p36workshop/lib/python3.6/site-packages/sklearn/linear_model/logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /home/lucia/anaconda3/envs/p36workshop/lib/python3.6/site-packages/sklearn/svm/base.py:931: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)

# %% [markdown]
# #### Matriz de confusión

# %%
plt.figure(figsize=(14, 10), dpi= 80, facecolor='w', edgecolor='k')

plt.subplot(2, 2, 1)
plot_confusion_matrix(confusion_matrix(y_train, model.predict(X_train_feature)),
                      classes=breast_cancer_data.target_names,
                      title='Matriz de confusión para entrenamiento (sin normalizar)')
plt.subplot(2, 2, 3)
plot_confusion_matrix(confusion_matrix(y_train, model.predict(X_train_feature)),
                      classes=breast_cancer_data.target_names, normalize=True,
                      title='Matriz de confusión para entrenamiento (normalizando)')

plt.subplot(2, 2, 2)
plot_confusion_matrix(confusion_matrix(y_val, model.predict(X_val_feature)),
                      classes=breast_cancer_data.target_names,
                      title='Matriz de confusión para validación (sin normalizar)')
plt.subplot(2, 2, 4)
plot_confusion_matrix(confusion_matrix(y_val, model.predict(X_val_feature)),
                      classes=breast_cancer_data.target_names, normalize=True,
                      title='Matriz de confusión para validación (normalizando)')

plt.show()

# %% [markdown]
# #### Visualización de la frontera de decisión

# %%
plt.figure(figsize=(14, 5), dpi=80, facecolor='w', edgecolor='k')

xx, yy, Z = classifier_boundary(np.r_[X_train_feature, X_val_feature], model)

cmap_dots = ListedColormap(['tomato', 'dodgerblue'])
cmap_back = ListedColormap(['lightcoral', 'skyblue'])

# Conjunto de entrenamiento
plt.subplot(1, 2, 1)
plt.pcolormesh(xx, yy, Z, cmap=cmap_back)
plt.scatter(X_train_feature[:, 0], X_train_feature[:, 1], c=y_train, cmap=cmap_dots, edgecolor='k', s=20)
plt.xlim(xx.min(), xx.max())
plt.ylim(yy.min(), yy.max())

plt.title("Conjunto de Entrenamiento")

# Conjunto de validación
plt.subplot(1, 2, 2)
plt.pcolormesh(xx, yy, Z, cmap=cmap_back)
plt.scatter(X_val_feature[:, 0], X_val_feature[:, 1], c=y_val, cmap=cmap_dots, edgecolor='k', s=20)
plt.xlim(xx.min(), xx.max())
plt.ylim(yy.min(), yy.max())
plt.title("Conjunto de Validación")

plt.show()

# %% [markdown]
# ### Vecinos más cercanos
#
# https://scikit-learn.org/stable/modules/generated/sklearn.neighbors.KNeighborsClassifier.html

# %%
n_neighbors =5 # TODO: Cantidad de vecinos a tener en cuenta
metric = 'euclidean' # TODO: Medida de distancia. Algunas opciones: cosine, euclidean, manhattan.

model = KNeighborsClassifier(n_neighbors=n_neighbors, metric=metric)
model.fit(X_train_feature, y_train)

print('Exactitud para entrenamiento: %.2f' %  accuracy_score(y_train, model.predict(X_train_feature)))
print('Exactitud para validación: %.2f' % accuracy_score(y_val, model.predict(X_val_feature)))
# Out:
# Exactitud para entrenamiento: 0.89
# Exactitud para validación: 0.85

# %% [markdown]
# #### Matriz de confusión

# %%
plt.figure(figsize=(14, 10), dpi= 80, facecolor='w', edgecolor='k')

plt.subplot(2, 2, 1)
plot_confusion_matrix(confusion_matrix(y_train, model.predict(X_train_feature)),
                      classes=breast_cancer_data.target_names,
                      title='Matriz de confusión para entrenamiento (sin normalizar)')
plt.subplot(2, 2, 3)
plot_confusion_matrix(confusion_matrix(y_train, model.predict(X_train_feature)),
                      classes=breast_cancer_data.target_names, normalize=True,
                      title='Matriz de confusión para entrenamiento (normalizando)')

plt.subplot(2, 2, 2)
plot_confusion_matrix(confusion_matrix(y_val, model.predict(X_val_feature)),
                      classes=breast_cancer_data.target_names,
                      title='Matriz de confusión para validación (sin normalizar)')
plt.subplot(2, 2, 4)
plot_confusion_matrix(confusion_matrix(y_val, model.predict(X_val_feature)),
                      classes=breast_cancer_data.target_names, normalize=True,
                      title='Matriz de confusión para validación (normalizando)')

plt.show()

# %% [markdown]
# #### Visualización de la frontera de decisión

# %%
plt.figure(figsize=(14, 5), dpi=80, facecolor='w', edgecolor='k')

xx, yy, Z = classifier_boundary(np.r_[X_train_feature, X_val_feature], model)

cmap_dots = ListedColormap(['tomato', 'dodgerblue'])
cmap_back = ListedColormap(['lightcoral', 'skyblue'])

# Conjunto de entrenamiento
plt.subplot(1, 2, 1)
plt.pcolormesh(xx, yy, Z, cmap=cmap_back)
plt.scatter(X_train_feature[:, 0], X_train_feature[:, 1], c=y_train, cmap=cmap_dots, edgecolor='k', s=20)
plt.xlim(xx.min(), xx.max())
plt.ylim(yy.min(), yy.max())
plt.title("Conjunto de Entrenamiento")

# Conjunto de validación
plt.subplot(1, 2, 2)
plt.pcolormesh(xx, yy, Z, cmap=cmap_back)
plt.scatter(X_val_feature[:, 0], X_val_feature[:, 1], c=y_val, cmap=cmap_dots, edgecolor='k', s=20)
plt.xlim(xx.min(), xx.max())
plt.ylim(yy.min(), yy.max())
plt.title("Conjunto de Validación")

plt.show()

# %% [markdown]
# ## Clasificación multiclase
#
# Ahora veremos clasificación multiclase. Muy similar al caso anterior, con la diferencia de que en este caso hay más de dos etiquetas posibles para clasificación. Se utilizará el método `one-vs-all` (o también `one-vs-rest`) para hacer posible la clasificaicón.
#
# Una vez más tenemos que decidir dos features para poder visualizar los modelos.
#
# ### Carga de datos

# %%
iris_data = load_iris()

# Utilizamos aproximadamente 80% de los datos para entrenamiento y 20% para validación
shuff_data = np.random.permutation(150)
shuff_train = shuff_data[:120]
shuff_val = shuff_data[120:]

X_train = iris_data['data'][shuff_train]
X_val = iris_data['data'][shuff_val]

y_train = iris_data['target'][shuff_train]
y_val = iris_data['target'][shuff_val]

feature_map = {feature: idx for idx, feature in enumerate(iris_data['feature_names'])}

print(iris_data['DESCR'])
# Out:
# .. _iris_dataset:
#
# Iris plants dataset
# --------------------
#
# **Data Set Characteristics:**
#
#     :Number of Instances: 150 (50 in each of three classes)
#     :Number of Attributes: 4 numeric, predictive attributes and the class
#     :Attribute Information:
#         - sepal length in cm
#         - sepal width in cm
#         - petal length in cm
#         - petal width in cm
#         - class:
#                 - Iris-Setosa
#                 - Iris-Versicolour
#                 - Iris-Virginica
#
#     :Summary Statistics:
#
#     ============== ==== ==== ======= ===== ====================
#                     Min  Max   Mean    SD   Class Correlation
#     ============== ==== ==== ======= ===== ====================
#     sepal length:   4.3  7.9   5.84   0.83    0.7826
#     sepal width:    2.0  4.4   3.05   0.43   -0.4194
#     petal length:   1.0  6.9   3.76   1.76    0.9490  (high!)
#     petal width:    0.1  2.5   1.20   0.76    0.9565  (high!)
#     ============== ==== ==== ======= ===== ====================
#
#     :Missing Attribute Values: None
#     :Class Distribution: 33.3% for each of 3 classes.
#     :Creator: R.A. Fisher
#     :Donor: Michael Marshall (MARSHALL%PLU@io.arc.nasa.gov)
#     :Date: July, 1988
#
# The famous Iris database, first used by Sir R.A. Fisher. The dataset is taken
# from Fisher's paper. Note that it's the same as in R, but not as in the UCI
# Machine Learning Repository, which has two wrong data points.
#
# This is perhaps the best known database to be found in the
# pattern recognition literature.  Fisher's paper is a classic in the field and
# is referenced frequently to this day.  (See Duda & Hart, for example.)  The
# data set contains 3 classes of 50 instances each, where each class refers to a
# type of iris plant.  One class is linearly separable from the other 2; the
# latter are NOT linearly separable from each other.
#
# .. topic:: References
#
#    - Fisher, R.A. "The use of multiple measurements in taxonomic problems"
#      Annual Eugenics, 7, Part II, 179-188 (1936); also in "Contributions to
#      Mathematical Statistics" (John Wiley, NY, 1950).
#    - Duda, R.O., & Hart, P.E. (1973) Pattern Classification and Scene Analysis.
#      (Q327.D83) John Wiley & Sons.  ISBN 0-471-22361-1.  See page 218.
#    - Dasarathy, B.V. (1980) "Nosing Around the Neighborhood: A New System
#      Structure and Classification Rule for Recognition in Partially Exposed
#      Environments".  IEEE Transactions on Pattern Analysis and Machine
#      Intelligence, Vol. PAMI-2, No. 1, 67-71.
#    - Gates, G.W. (1972) "The Reduced Nearest Neighbor Rule".  IEEE Transactions
#      on Information Theory, May 1972, 431-433.
#    - See also: 1988 MLC Proceedings, 54-64.  Cheeseman et al"s AUTOCLASS II
#      conceptual clustering system finds 3 classes in the data.
#    - Many, many more ...

# %%
print("Listado de atributos\n====================")
for feature in iris_data['feature_names']:
    print("- %s" % feature)
# Out:
# Listado de atributos
# ====================
# - sepal length (cm)
# - sepal width (cm)
# - petal length (cm)
# - petal width (cm)

# %%
# Seleccionamos dos atributo de los listados en el apartado anterior, uno para el eje x y otro para el eje y
# TODO: Cambiar los atributos y ver como se modifica el resultado
#x_feature = 'sepal length (cm)'
x_feature = 'petal length (cm)'
y_feature = 'sepal width (cm)'

x_feature_col = feature_map[x_feature]
y_feature_col = feature_map[y_feature]
X_train_feature = X_train[:, [x_feature_col, y_feature_col]]
X_val_feature = X_val[:, [x_feature_col, y_feature_col]]

# %% [markdown]
# ### Regresión logística
#
# https://scikit-learn.org/stable/modules/generated/sklearn.linear_model.LogisticRegression.html

# %%
penalty = 'l2' # TODO: Tipo de regularización: l1 (valor absoluto), l2 (cuadrados).
alpha = 0.001 # TODO: Parámetro de regularización. También denominado como parámetro `lambda`. Debe ser mayor que 0.

model = LogisticRegression(penalty=penalty, C=1./alpha, multi_class='ovr')
model.fit(X_train_feature, y_train)

print('Exactitud para entrenamiento: %.2f' %  accuracy_score(y_train, model.predict(X_train_feature)))
print('Exactitud para validación: %.2f' % accuracy_score(y_val, model.predict(X_val_feature)))
# Out:
# Exactitud para entrenamiento: 0.96
# Exactitud para validación: 0.93
# /home/lucia/anaconda3/envs/p36workshop/lib/python3.6/site-packages/sklearn/linear_model/logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)

# %% [markdown]
# #### Matriz de confusión

# %%
plt.figure(figsize=(14, 10), dpi= 80, facecolor='w', edgecolor='k')

plt.subplot(2, 2, 1)
plot_confusion_matrix(confusion_matrix(y_train, model.predict(X_train_feature)),
                      classes=iris_data.target_names,
                      title='Matriz de confusión para entrenamiento (sin normalizar)')
plt.subplot(2, 2, 3)
plot_confusion_matrix(confusion_matrix(y_train, model.predict(X_train_feature)),
                      classes=iris_data.target_names, normalize=True,
                      title='Matriz de confusión para entrenamiento (normalizando)')

plt.subplot(2, 2, 2)
plot_confusion_matrix(confusion_matrix(y_val, model.predict(X_val_feature)),
                      classes=iris_data.target_names,
                      title='Matriz de confusión para validación (sin normalizar)')
plt.subplot(2, 2, 4)
plot_confusion_matrix(confusion_matrix(y_val, model.predict(X_val_feature)),
                      classes=iris_data.target_names, normalize=True,
                      title='Matriz de confusión para validación (normalizando)')

plt.show()

# %% [markdown]
# #### Visualización de la frontera de decisión

# %%
plt.figure(figsize=(14, 5), dpi=80, facecolor='w', edgecolor='k')

xx, yy, Z = classifier_boundary(np.r_[X_train_feature, X_val_feature], model)

cmap_dots = ListedColormap(['tomato', 'dodgerblue', 'goldenrod'])
cmap_back = ListedColormap(['lightcoral', 'skyblue', 'palegoldenrod'])

# Conjunto de entrenamiento
plt.subplot(1, 2, 1)
plt.pcolormesh(xx, yy, Z, cmap=cmap_back)
plt.scatter(X_train_feature[:, 0], X_train_feature[:, 1], c=y_train, cmap=cmap_dots, edgecolor='k', s=20)
plt.xlim(xx.min(), xx.max())
plt.ylim(yy.min(), yy.max())
plt.title("Conjunto de Entrenamiento")

# Conjunto de validación
plt.subplot(1, 2, 2)
plt.pcolormesh(xx, yy, Z, cmap=cmap_back)
plt.scatter(X_val_feature[:, 0], X_val_feature[:, 1], c=y_val, cmap=cmap_dots, edgecolor='k', s=20)
plt.xlim(xx.min(), xx.max())
plt.ylim(yy.min(), yy.max())
plt.title("Conjunto de Validación")

plt.show()

# %% [markdown]
# ### Vecinos más cercanos
#
# https://scikit-learn.org/stable/modules/generated/sklearn.neighbors.KNeighborsClassifier.html

# %%
n_neighbors = 5# TODO: Cantidad de vecinos a tener en cuenta
metric = 'cosine' # TODO: Medida de distancia. Algunas opciones: cosine, euclidean, manhattan.

model = KNeighborsClassifier(n_neighbors=n_neighbors, metric=metric)
model.fit(X_train_feature, y_train)

print('Exactitud para entrenamiento: %.2f' %  accuracy_score(y_train, model.predict(X_train_feature)))
print('Exactitud para validación: %.2f' % accuracy_score(y_val, model.predict(X_val_feature)))
# Out:
# Exactitud para entrenamiento: 0.91
# Exactitud para validación: 0.87

# %% [markdown]
# #### Matriz de confusión

# %%
plt.figure(figsize=(14, 10), dpi= 80, facecolor='w', edgecolor='k')

plt.subplot(2, 2, 1)
plot_confusion_matrix(confusion_matrix(y_train, model.predict(X_train_feature)),
                      classes=iris_data.target_names,
                      title='Matriz de confusión para entrenamiento (sin normalizar)')
plt.subplot(2, 2, 3)
plot_confusion_matrix(confusion_matrix(y_train, model.predict(X_train_feature)),
                      classes=iris_data.target_names, normalize=True,
                      title='Matriz de confusión para entrenamiento (normalizando)')

plt.subplot(2, 2, 2)
plot_confusion_matrix(confusion_matrix(y_val, model.predict(X_val_feature)),
                      classes=iris_data.target_names,
                      title='Matriz de confusión para validación (sin normalizar)')
plt.subplot(2, 2, 4)
plot_confusion_matrix(confusion_matrix(y_val, model.predict(X_val_feature)),
                      classes=iris_data.target_names, normalize=True,
                      title='Matriz de confusión para validación (normalizando)')

plt.show()

# %% [markdown]
# #### Visualización de la frontera de decisión

# %%
plt.figure(figsize=(14, 5), dpi=80, facecolor='w', edgecolor='k')

xx, yy, Z = classifier_boundary(np.r_[X_train_feature, X_val_feature], model)

cmap_dots = ListedColormap(['tomato', 'dodgerblue', 'goldenrod'])
cmap_back = ListedColormap(['lightcoral', 'skyblue', 'palegoldenrod'])

# Conjunto de entrenamiento
plt.subplot(1, 2, 1)
plt.pcolormesh(xx, yy, Z, cmap=cmap_back)
plt.scatter(X_train_feature[:, 0], X_train_feature[:, 1], c=y_train, cmap=cmap_dots, edgecolor='k', s=20)
plt.xlim(xx.min(), xx.max())
plt.ylim(yy.min(), yy.max())
plt.title("Conjunto de Entrenamiento")

# Conjunto de validación
plt.subplot(1, 2, 2)
plt.pcolormesh(xx, yy, Z, cmap=cmap_back)
plt.scatter(X_val_feature[:, 0], X_val_feature[:, 1], c=y_val, cmap=cmap_dots, edgecolor='k', s=20)
plt.xlim(xx.min(), xx.max())
plt.ylim(yy.min(), yy.max())
plt.title("Conjunto de Validación")

plt.show()

# %% [markdown]
# aumentando la contidad de vecinos, en ambos tipos de clasificaciones (binarias y multiclase), mejora la clasificación
